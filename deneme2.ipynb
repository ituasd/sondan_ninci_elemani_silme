# %%
d=[1,2,5,6,7]
print(d[-2])
# Out:
# 6

# %%
def sondan_ninci_elemani_sil(b=[],n=int):
    if len(b)<n:
        print("dizide o kadar eleman yok")
        return b;
    b.pop(len(b)-n);
    return b;

# %%
print(sondan_ninci_elemani_sil(d,5));
# Out:
# [2, 5, 6, 7]

# %%
print(sondan_ninci_elemani_sil(d,7))
# Out:
# dizide o kadar eleman yok
# [2, 5, 6, 7]
